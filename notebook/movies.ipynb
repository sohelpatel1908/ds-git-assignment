# %%
import pandas as pd 
import numpy as np 

df = pd.read_csv("D:\\CreateBot Labs Internship\\Day 2\\GitHub Assignment\\ds-git-assignment\\data\\dummy_dataset.csv")

# %%
df.head()
# Out:
#         movie_name  released_year  rating           director
# 0        Inception           2010     8.8  Christopher Nolan
# 1     Interstellar           2014     8.6  Christopher Nolan
# 2  The Dark Knight           2008     9.0  Christopher Nolan
# 3          Titanic           1997     7.9      James Cameron
# 4           Avatar           2009     7.8      James Cameron
